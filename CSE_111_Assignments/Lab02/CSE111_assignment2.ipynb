# %%
#Task 1

class DataType:
    def __init__(self, name, value):
        self.name = name
        self.value = value

data_type1 = DataType('Integer' , 1234)
print(data_type1.name)
print(data_type1.value)
print('=====================')
data_type2 = DataType('String', 'Hello')
print(data_type2.name)
print(data_type2.value)
print('=====================')
data_type3 = DataType('Float', 4.0)
print(data_type3.name)
print(data_type3.value)
# Out:
# Integer
# 1234
# ...
# String
# Hello
# ...
# Float
# 4.0

# %%
#Task 2

class Flower:
    def __init__(self):
        pass

flower1 = Flower()
flower1.name="Rose"
flower1.color="Red"
flower1.num_of_petal=6
print("Name of this flower:", flower1.name)
print("Color of this flower:",flower1.color)
print("Number of petal:",flower1.num_of_petal)
print("=====================")
flower2 = Flower()
flower2.name="Orchid"
flower2.color="Purple"
flower2.num_of_petal=4
print("Name of this flower:",flower2.name)
print("Color of this flower:",flower2.color)
print ("Number of petal:",flower2. num_of_petal)

print("flower1 memory adress: ", flower1)
print("flower2 memory adress: ", flower2)
if flower2 == flower1:
    print("They are same")
else:
    print("They are different")
# Out:
# Name of this flower: Rose
# Color of this flower: Red
# Number of petal: 6
# ...
# Name of this flower: Orchid
# Color of this flower: Purple
# Number of petal: 4
# flower1 memory adress:  <__main__.Flower object at 0x7f7aae794b10>
# flower2 memory adress:  <__main__.Flower object at 0x7f7aae794310>
# They are different

# %%
#Task 3

class Joker:
    def __init__(self, name, power, is_he_psycho):
        self.name = name
        self.power = power
        self.is_he_psycho = is_he_psycho

j1 = Joker("Heath Ledger", "Mind Game", False)
print(j1.name)
print(j1.power)
print(j1.is_he_psycho)
print("=====================")
j2 = Joker("Joaquin Phoenix", "Laughing out Loud", True)
print(j2.name)
print(j2.power)
print(j2.is_he_psycho)
print("=====================")
if j1 == j2:
    print("same")
else:
    print("different")
j2.name = "Heath Ledger"
if j1.name == j2.name:
    print("same")
else:
    print("different")
print("=====================")
print("In first if else j1 and j2 is in different memory location")
print("Because the string stored in j1.name and j2.name are same")
# Out:
# Heath Ledger
# Mind Game
# False
# ...
# Joaquin Phoenix
# Laughing out Loud
# True
# ...
# different
# same
# ...
# In first if else j1 and j2 is in different memory location
# Because the string stored in j1.name and j2.name are same

# %%
class Triangle:
    def __init__(self, base, height):
        self.base = base
        self.height = height
        self.area = 0.5 * base * height
    
    def __str__(self):
        return f"0.5 * {self.base} * {self.height} = {self.area}"

t1 = Triangle(6, 4)
t2 = Triangle(6, 2)
print(f"Triangle Base = {t1.base}\nTriangle Height = {t1.height}\nTriangle Area = {t1.area}\n")

print(t1)

print(f"Triangle Base = {t2.base}\nTriangle Height = {t2.height}\nTriangle Area = {t2.area}\n")

print(t2)
# Out:
# Triangle Base = 6
# Triangle Height = 4
# Triangle Area = 12.0
#
# 0.5 * 6 * 4 = 12.0
# Triangle Base = 6
# Triangle Height = 2
# Triangle Area = 6.0
#
# 0.5 * 6 * 2 = 6.0

# %%
#Task 4

class Pokemon:
    def __init__(self, pokemon1_name, pokemon2_name, pokemon1_power, pokemon2_power, damage_rate):
        self.pokemon1_name = pokemon1_name
        self.pokemon2_name = pokemon2_name
        self.pokemon1_power = pokemon1_power
        self.pokemon2_power = pokemon2_power
        self.damage_rate = damage_rate

team_pika = Pokemon("pikachu", "charmander", 90, 60, 10)
print('=======Team 1=======')
print('Pokemon 1:', team_pika.pokemon1_name, team_pika.pokemon1_power)
print('Pokemon 2:',team_pika.pokemon2_name, team_pika.pokemon2_power)
pika_combined_power = (team_pika.pokemon1_power + team_pika.pokemon2_power) * team_pika.damage_rate
print('Combined Power:', pika_combined_power)

#==================================================

team_bulb = Pokemon("bulbasaur", "squirtle", 80, 70, 9)
print('=======Team 2=======')
print('Pokemon 1:', team_bulb.pokemon1_name, team_bulb.pokemon1_power)
print('Pokemon 2:',team_bulb.pokemon2_name, team_bulb.pokemon2_power)
pika_combined_power = (team_bulb.pokemon1_power + team_bulb.pokemon2_power) * team_bulb.damage_rate
print('Combined Power:', pika_combined_power)
# Out:
# =======Team 1=======
# Pokemon 1: pikachu 90
# Pokemon 2: charmander 60
# Combined Power: 1500
# =======Team 2=======
# Pokemon 1: bulbasaur 80
# Pokemon 2: squirtle 70
# Combined Power: 1350

# %%
#Task 5

class Player:
    def __init__(self):
        pass

player1 = Player()
player1.name = "Ronaldo"
player1.jersy_number = 9
player1.position = "Striker"
print("Name of the Player:", player1.name)
print("Jersey Number of player:", player1.jersy_number)
print("Position of player:", player1.position)
print("===========================")
player2 = Player()
player2.name = "Neuer"
player2.jersy_number = 1
player2.position = "Goal Keeper"
print("Name of the player:", player2.name)
print("Jersey Number of player:", player2.jersy_number)
print("Position of player:", player2.position)
# Out:
# Name of the Player: Ronaldo
# Jersey Number of player: 9
# Position of player: Striker
# ...
# Name of the player: Neuer
# Jersey Number of player: 1
# Position of player: Goal Keeper

# %%
#Task 6

class Country:
    def __init__(self):
        self.name = "Bangladesh"
        self.continent = "Asia"
        self.capital = "Dhaka"
        self.fifa_ranking = 187

country = Country()
print("Name:", country.name)
print("Continent:",country.continent)
print("Capital:",country.capital)
print("Fifa Ranking:",country.fifa_ranking)
print('===================')
country.name = "Belgium"
country.continent = "Europe"
country.capital = "Brussels"
country.fifa_ranking = 1
print("Name:",country.name)
print("Continent:",country.continent)
print("Capital:",country.capital)
print("Fifa Ranking:",country.fifa_ranking)
# Out:
# Name: Bangladesh
# Continent: Asia
# Capital: Dhaka
# Fifa Ranking: 187
# ...
# Name: Belgium
# Continent: Europe
# Capital: Brussels
# Fifa Ranking: 1

# %%
#Task 7

class DemonSlayer:
    def __init__(self, name, style, number_of_technique, kill):
        self.name = name
        self.style = style
        self.number_of_technique = number_of_technique
        self.kill = kill

tanjiro = DemonSlayer("Tanjiro", "Water Breathing", 10, 10)
print("Name:",tanjiro.name)
print("Style:",tanjiro.style)
print(f"Knows {tanjiro.number_of_technique} technique(s) and has killed {tanjiro.kill} demon(s)")
print("===================")
zenitsu = DemonSlayer("Zenitsu", "Thunder Breathing", 1, 4)
print("Name:",zenitsu.name)
print("Fighting Style:",zenitsu.style)
print(f"Knows {zenitsu.number_of_technique} technique(s) and has killed {zenitsu.kill} demon(s)")
print("===================")
inosuke = DemonSlayer("Inosuke", "Beast Breathing", 5, 7)
print("Name:",inosuke.name)
print("Fighting Style:",inosuke.style)
print(f"Knows {inosuke.number_of_technique} technique(s) and has killed {inosuke.kill} demon(s)")
print("===================")
print(f"{tanjiro.name}, {zenitsu.name}, {inosuke.name} knows total {tanjiro.number_of_technique + zenitsu.number_of_technique + inosuke.number_of_technique} techniques")
print(f"They have killed total {tanjiro.kill + zenitsu.kill + inosuke.kill} demons")
# Out:
# Name: Tanjiro
# Style: Water Breathing
# Knows 10 technique(s) and has killed 10 demon(s)
# ...
# Name: Zenitsu
# Fighting Style: Thunder Breathing
# Knows 1 technique(s) and has killed 4 demon(s)
# ...
# Name: Inosuke
# Fighting Style: Beast Breathing
# Knows 5 technique(s) and has killed 7 demon(s)
# ...
# Tanjiro, Zenitsu, Inosuke knows total 16 techniques
# They have killed total 21 demons

# %%
#Task 8

class box:
    def __init__(self, info):
        print("Creating a Box!")
        cubic_unit = info[0]*info[1]*info[2]
        print("Volume of the box is " + str(cubic_unit) + " cubic units." )
        self.height = info[0]
        self.width = info[1]
        self.breadth = info[2]
print("Box 1")
b1 = box([10,10,10])
print("=========================")
print("Height:", b1.height)
print("Width:", b1.width)
print("Breadth:", b1.breadth)
print("-------------------------")
print("Box 2")
b2 = box((30,10,10))
print("=========================")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
print("-------------------------")
print("Box 3")
b3 = b2
print("Height:", b3.height)
print("Width:", b3.width)
print("Breadth:", b3.breadth)
# Out:
# Box 1
# Creating a Box!
# Volume of the box is 1000 cubic units.
# ...
# Height: 10
# Width: 10
# Breadth: 10
# -------------------------
# Box 2
# Creating a Box!
# Volume of the box is 3000 cubic units.
# ...
# Height: 30
# Width: 10
# Breadth: 10
# Updating Box 2!
# Height: 300
# Width: 10
# Breadth: 10
# -------------------------
# Box 3
# Height: 300
# Width: 10
# Breadth: 10

# %%
class box:
    def __init__(self, info):
        print("Creating a Box!")
        # self.cubic_unit = info[0]*info[1]*info[2]
        # print("Volume of the box is " + str(cubic_unit) + " cubic units." )
        self.height = info[0]
        self.width = info[1]
        self.breadth = info[2]
    def __str__(self):
        return f"Volume of the box is {self.height*self.width*self.breadth} cubic units."
print("Box 1")
b1 = box([10,10,10])
print(b1)
print("=========================")
print("Height:", b1.height)
print("Width:", b1.width)
print("Breadth:", b1.breadth)
print("-------------------------")
print("Box 2")

b2 = box((30,10,10))
print(b2)
print("=========================")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
print("-------------------------")
print("Box 3")
b3 = b2
print("Height:", b3.height)
print("Width:", b3.width)
print("Breadth:", b3.breadth)
# Out:
# Box 1
# Creating a Box!
# Volume of the box is 1000 cubic units.
# ...
# Height: 10
# Width: 10
# Breadth: 10
# -------------------------
# Box 2
# Creating a Box!
# Volume of the box is 3000 cubic units.
# ...
# Height: 30
# Width: 10
# Breadth: 10
# Updating Box 2!
# Height: 300
# Width: 10
# Breadth: 10
# -------------------------
# Box 3
# Height: 300
# Width: 10
# Breadth: 10

# %%
class box:
    def __init__(self, info):
        print("Creating a Box!")
        self.cubic_unit = info[0]*info[1]*info[2]
        # print("Volume of the box is " + str(cubic_unit) + " cubic units." )
        self.height = info[0]
        self.width = info[1]
        self.breadth = info[2]
    def __str__(self):
        return f"Volume of the box is {(self.cubic_unit)} cubic units."
print("Box 1")
b1 = box([10,10,10])
print(b1)
print("=========================")
print("Height:", b1.height)
print("Width:", b1.width)
print("Breadth:", b1.breadth)
print("-------------------------")
print("Box 2")

b2 = box((30,10,10))
print(b2)
print("=========================")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
print("-------------------------")
print("Box 3")
b3 = b2
print("Height:", b3.height)
print("Width:", b3.width)
print("Breadth:", b3.breadth)
# Out:
# Box 1
# Creating a Box!
# Volume of the box is 1000 cubic units.
# ...
# Height: 10
# Width: 10
# Breadth: 10
# -------------------------
# Box 2
# Creating a Box!
# Volume of the box is 3000 cubic units.
# ...
# Height: 30
# Width: 10
# Breadth: 10
# Updating Box 2!
# Height: 300
# Width: 10
# Breadth: 10
# -------------------------
# Box 3
# Height: 300
# Width: 10
# Breadth: 10

# %%
#Task 9
class buttons:
    def __init__(self, word, spaces, border):
        self.word = word
        self.spaces = spaces
        self.border = border
        self.top_bottom = 1 + self.spaces + len(self.word) + self.spaces + 1
        print(f"{self.word} Button Specifications:")
        print("Button name:", self.word)
        print("Number of the border characters for the top and the bottom:", self.top_bottom)
        print("Number of spaces between the left side border and the first character of the button name:", self.spaces)
        print("Number of spaces between the right side border and the last character of the button name:", self.spaces)
        print("Characters representing the borders:", self.border)
        n = " "
        print(f"{self.top_bottom*self.border}\n{self.border}{self.spaces*n}{self.word}{self.spaces*n}{self.border}\n{self.top_bottom*self.border}")

word = "CANCEL"  
spaces = 10
border = 'x'
self = buttons(word, spaces, border)
print("=======================================================")
b2 = buttons("Notify",3, '!')
print("=======================================================")
b3 = buttons('SAVE PROGRESS', 5, '$')
# Out:
# CANCEL Button Specifications:
# Button name: CANCEL
# Number of the border characters for the top and the bottom: 28
# Number of spaces between the left side border and the first character of the button name: 10
# Number of spaces between the right side border and the last character of the button name: 10
# Characters representing the borders: x
# xxxxxxxxxxxxxxxxxxxxxxxxxxxx
# x          CANCEL          x
# xxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ...
# Notify Button Specifications:
# Button name: Notify
# Number of the border characters for the top and the bottom: 14
# Number of spaces between the left side border and the first character of the button name: 3
# Number of spaces between the right side border and the last character of the button name: 3
# Characters representing the borders: !
# !!!!!!!!!!!!!!
# !   Notify   !
# !!!!!!!!!!!!!!
# ...
# SAVE PROGRESS Button Specifications:
# Button name: SAVE PROGRESS
# Number of the border characters for the top and the bottom: 25
# ...

# %%
#Task 9

class buttons:
    def __init__(self, word, spaces, border):
        self.word = word
        self.spaces = spaces
        self.border = border
 
word = "CANCEL"
spaces = 10
border = 'x'
b1 = buttons(word, spaces, border)
top_bottom = 1 + b1.spaces + len(b1.word) + b1.spaces + 1
print("CANCEL Button Specifications:")
print("Button name:", b1.word)
print("Number of the border characters for the top and the bottom:", top_bottom)
print("Number of spaces between the left side border and the first character of the button name:", b1.spaces)
print("Number of spaces between the right side border and the last character of the button name:", b1.spaces)
print("Characters representing the borders:", b1.border)
n = " "
print(f"{top_bottom*b1.border}\n{b1.border}{b1.spaces*n}{b1.word}{b1.spaces*n}{b1.border}\n{top_bottom*b1.border}")
print("=======================================================")

b2 = buttons("Notify",3, '!')
top_bottom = 1 + b2.spaces + len(b2.word) + b2.spaces + 1
print("Notify Button Specifications:")
print("Button name:", b2.word)
print("Number of the border characters for the top and the bottom:", top_bottom)
print("Number of spaces between the left side border and the first character of the button name:", b2.spaces)
print("Number of spaces between the right side border and the last character of the button name:", b2.spaces)
print("Characters representing the borders:", b2.border)
n = " "
print(f"{top_bottom*b2.border}\n{b2.border}{b2.spaces*n}{b2.word}{b2.spaces*n}{b2.border}\n{top_bottom*b2.border}")
print("=======================================================")

b3 = buttons('SAVE PROGRESS', 5, '$')
top_bottom = 1 + b3.spaces + len(b3.word) + b3.spaces + 1
print("Button name:", b3.word)
print("Number of the border characters for the top and the bottom:", top_bottom)
print("Number of spaces between the left side border and the first character of the button name:", b3.spaces)
print("Number of spaces between the right side border and the last character of the button name:", b3.spaces)
print("Characters representing the borders:", b3.border)
n = " "
print(f"{top_bottom*b3.border}\n{b3.border}{b3.spaces*n}{b3.word}{b3.spaces*n}{b3.border}\n{top_bottom*b3.border}")
# Out:
# CANCEL Button Specifications:
# Button name: CANCEL
# Number of the border characters for the top and the bottom: 28
# Number of spaces between the left side border and the first character of the button name: 10
# Number of spaces between the right side border and the last character of the button name: 10
# Characters representing the borders: x
# xxxxxxxxxxxxxxxxxxxxxxxxxxxx
# x          CANCEL          x
# xxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ...
# Notify Button Specifications:
# Button name: Notify
# Number of the border characters for the top and the bottom: 14
# Number of spaces between the left side border and the first character of the button name: 3
# Number of spaces between the right side border and the last character of the button name: 3
# Characters representing the borders: !
# !!!!!!!!!!!!!!
# !   Notify   !
# !!!!!!!!!!!!!!
# ...
# Button name: SAVE PROGRESS
# Number of the border characters for the top and the bottom: 25
# ...

# %%
#Task 10

class Wadiya():
    def __init__(self):
        self.name = "Aladeen"
        self.designation = "President Prime Minister Admiral General"
        self.num_of_wife = 100
        self.dictator = True

print("Part 1:")
p1 = Wadiya()
print("Name of President:", p1.name)
print("Designation:", p1.designation)
print("number of wife:", p1.num_of_wife)
print("Name of President:", p1.name)
print("Is he/she a dictator:", p1.dictator)


print("Part 2:")
p1.name = "Donald Trump"
p1.designation = "President"
p1.num_of_wife = 1
p1.dictator = False
print("Name of President:", p1.name)
print("Designation:", p1.designation)
print("number of wife:", p1.num_of_wife)
print("Is he/she a dictator:", p1.dictator)

print("previous information lost")
# Out:
# Part 1:
# Name of President: Aladeen
# Designation: President Prime Minister Admiral General
# number of wife: 100
# Name of President: Aladeen
# Is he/she a dictator: True
# Part 2:
# Name of President: Donald Trump
# Designation: President
# number of wife: 1
# Is he/she a dictator: False
# previous information lost

# %%
#Task 10

class Wadiya():
    def __init__(self):
        self.name = "Aladeen"
        self.designation = "President Prime Minister Admiral General"
        self.num_of_wife = 100
        self.dictator = True
def wadiya_xoss(name, designation, num_of_wife, dictator):
    print("Name of President:", name)
    print("Designation:", designation)
    print("number of wife:", num_of_wife)
    print("Is he/she a dictator:", dictator)

p1 = Wadiya()
print("Part 1:")
wadiya_xoss(p1.name, p1.designation, p1.num_of_wife, p1.dictator)

print("Part 2:")
p1.name = "Donald Trump"
p1.designation = "President"
p1.num_of_wife = 1
p1.dictator = False
wadiya_xoss(p1.name, p1.designation, p1.num_of_wife, p1.dictator)

print("previous information lost")
# Out:
# Part 1:
# Name of President: Aladeen
# Designation: President Prime Minister Admiral General
# number of wife: 100
# Is he/she a dictator: True
# Part 2:
# Name of President: Donald Trump
# Designation: President
# number of wife: 1
# Is he/she a dictator: False
# previous information lost
