# %% [markdown]
# **Task 1**

# %%
import PIL.Image
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
Letter_S = np.array( [[255, 0, 0, 0, 255,255, 255, 0, 255, 0, 0, 0, 255, 0, 0, 0, 255],
                      [255, 0, 0, 0, 0, 255, 255, 0, 255, 0, 255, 255, 255, 0, 255, 0, 255],
                      [255, 0, 255, 0, 0, 0, 255, 0, 255, 0, 0, 0, 255, 0, 0, 0, 255],
                      [255, 0, 255, 255, 0, 0, 0, 0, 255, 0, 255, 0, 255, 0, 255, 0, 255],
                      [255, 0, 255, 255, 255, 0, 0, 0, 255, 0, 0, 0, 255, 0, 0, 0, 255]])

plt.imshow(Letter_S,cmap='gray')

# %%
#Task2
