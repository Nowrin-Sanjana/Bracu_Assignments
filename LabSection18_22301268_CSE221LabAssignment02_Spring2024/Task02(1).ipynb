# %%
inp = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment02_Spring2024/input02(1).txt", "r")
output = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment02_Spring2024/output02(1).txt","w")
var = inp.read().split("\n")
len1, len2 = int(var[0]), int(var[2])
l1 = list(map(int, var[1].split(" ")))
l2 = list(map(int, var[3].split(" ")))
sorted_arr = sorted(l1+l2)
for item in sorted_arr:
    output.write("".join(str(item)+" "))
inp.close()
output.close()
