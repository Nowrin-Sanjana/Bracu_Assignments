# %%
inp = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment04_Spring2024/input2_1.txt", "r")
output = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment04_Spring2024/output2_1.txt", "w")
vertices, edges = map(int, inp.readline().split(" "))
var=inp.read().split('\n')
source = int(var[0][0])
def BFS(G, s):
    visited = [None] * (vertices+1)
    queue = []
    queue.append(s)
    visited[s] = 1
    while queue:
        current = queue.pop(0)
        output.write(str(current)+" ")
        for neighbor in G[current]:
            if visited[neighbor]!= 1:
                queue.append(neighbor)
                visited[neighbor] = 1
G = {}
for k in range(1, vertices+1):
    G[k]=[]
for iter in range(edges):
    u,v = list(map(int,var[iter].split(" ")))
    G[u].append((v))
    G[v].append((u))
BFS(G, source)
inp.close()
output.close()

# %%
inp = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment04_Spring2024/input2_1.txt", "r")
output = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment04_Spring2024/output2_1.txt", "w")
vertices, edges = map(int, inp.readline().split(" "))
var=inp.read().split('\n')
source = int(var[0][0])
G = {}
for k in range(1, vertices+1):
    G[k] = []
for iter in range(edges):
    u, v = list(map(int,var[iter].split(" ")))
    G[u].append((v))
    G[v].append((u))

def bfs(G, s):
    visited = [None]*(vertices+1)
    queue = []
    queue.append(s)
    visited[s] = 1
    while queue:
        current = queue.pop(0)
        print(str(current)+" ")
        for n in G[current]:
            if visited[n]!=1:
                visited[n] = 1
                queue.append(n)
bfs(G, source)

print(G)
# Out:
# 1
# 3
# 4
# 2
# {1: [3, 4], 2: [3], 3: [1, 2], 4: [1]}
