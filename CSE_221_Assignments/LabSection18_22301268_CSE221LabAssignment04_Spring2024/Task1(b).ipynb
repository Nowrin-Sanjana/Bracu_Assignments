# %%
inp = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment04_Spring2024/input1(b)_3.txt", "r")
output = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment04_Spring2024/output1(b)_3.txt", "w")
vertices, edges = map(int, inp.readline().split(" "))
store = {}
for iter in range(edges):
    u,v,w = tuple(map(int,inp.readline().split(" ")))
    if u not in store:
        store[u] = [(v, w)]
    else:
        store[u].append((v, w))
for vertex in range(0, vertices + 1):
    edges_list = store.get(vertex, [])
    edges_str = ""
    for v, w in edges_list:
        edges_str += f"({v},{w}) "
    output.write(f"{vertex} : {edges_str}\n")
inp.close()
output.close()

# %%
inp = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment04_Spring2024/input1(b)_3.txt", "r")
output = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment04_Spring2024/output1(b)_3.txt", "w")
vertices, edges = map(int, inp.readline().split(" "))
store = {}
for iter in range(edges):
    u, v, w =  map(int, inp.readline().split(" "))
    if u not in store:
        store[u] = [(v, w)]
    else:
        store[u].append((v, w))
for vertex in range(0, vertices+1):
    edges_list = store.get(vertex, [])
    edges_str = ""
    for v, w in edges_list:
        edges_str += f"({v},{w}) "
        print(edges_str)
    output.write(f"{vertex} : {edges_str}\n")
# print(edges_list)
# print(store)
# Out:
# (9,4)
# (1,10)
# (1,15)
# (1,15) (9,8)
# (1,15) (9,8) (8,4)
# (1,15) (9,8) (8,4) (7,3)
# (3,2)
# (4,7)
# (4,7) (3,1)
# (4,7) (3,1) (8,2)
# (1,13)
# (7,5)
# (4,8)
# (4,8) (2,10)
# (4,8) (2,10) (2,12)
