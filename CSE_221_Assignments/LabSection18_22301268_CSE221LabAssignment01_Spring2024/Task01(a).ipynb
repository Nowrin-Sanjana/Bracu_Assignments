# %%
with open("/content/drive/MyDrive/Semester/6th Semester/CSE221/18_22301268_CSE221_Lab01_Spring2024/input1a.txt", "r") as inp:
    output = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/18_22301268_CSE221_Lab01_Spring2024/output1a.txt", "w")
    input_num = int(inp.readline())
    for i in range(input_num):
        num = int(inp.readline())
        if num%2 == 0:
            output.write(f"{num} is an Even number.\n")
        else:
            output.write(f"{num} is an Odd number.\n")
    output.close()
