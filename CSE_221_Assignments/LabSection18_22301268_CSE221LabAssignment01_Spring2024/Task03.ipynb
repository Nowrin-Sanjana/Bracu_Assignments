# %%
with open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment01_Spring2024/input3.txt", "r") as inp:
    output = open("/content/drive/MyDrive/Semester/6th Semester/CSE221/LabSection18_22301268_CSE221LabAssignment01_Spring2024/output3.txt", "w")
    inp_num = int(inp.readline())
    list_ids = list(map(int, inp.readline().split(" ")))
    list_marks = list(map(int, inp.readline().split(" ")))
    def insertion_sort(list_ids, list_marks):
        for i in range(1, inp_num):
            key_marks = list_marks[i]
            key_ids = list_ids[i]
            j = i - 1
            while j >= 0 and key_marks > list_marks[j]:
                list_marks[j + 1] = list_marks[j]
                list_ids[j + 1] = list_ids[j]
                j -= 1
            list_marks[j + 1] = key_marks
            list_ids[j + 1] = key_ids
        return list_ids, list_marks
    s = insertion_sort(list_ids, list_marks)
    for i in range(inp_num):
        if i == inp_num - 1:
            output.write(f"ID: {list_ids[i]} Mark: {list_marks[i]}")
            break
        if list_marks[i] == list_marks[i+1]:
            for j in range(i,len(list_marks)):
                for k in range(j+1,len(list_marks)):
                    if list_marks[j]==list_marks[k]:
                        if list_ids[j]>list_ids[k]:
                            list_ids[j],list_ids[k]=list_ids[k],list_ids[j]
        output.write(f"ID: {list_ids[i]} Mark: {list_marks[i]}\n")
    output.close()
# Out:
# ID: 5 Mark: 10
