# %% [markdown]
# Task 1

# %%
#Write the Python code of a program that reads two numbers from the user, and prints their sum, product, and difference.

variable1 = int (input("Enter the 1st digit: "))
variable2 = int (input("Enter the second digit: "))
total = (variable1 + variable2)
product = (variable1 * variable2)
difference = (variable1 - variable2)
print("sum= ", total)
print(product)
print(difference)
# Out:
# Enter the 1st digit: 4
# Enter the second digit: 5
# sum=  9
# 20
# -1

# %% [markdown]
# Task 2

# %%
#Write the Python code of a program that reads the radius of a circle and prints its circumference and area.

import math
radius = float(input("Value of the radius: "))
area = math.pi * math.pow(radius, 2) # or area = math.pi * radius ** 2
circumference = 2 * math.pi * radius
print("Area of the circle :", "{:.2f}" .format(area))
print("Circumference of the circle :", "{:.2f}" .format(circumference))
# Out:
# Value of the radius: 3
# Area of the circle : 28.27
# Circumference of the circle : 18.85

# %% [markdown]
# Task 3

# %%
#Write the Python code of a program that reads two numbers from the user. 
#The program should then print "First is greater" if the first number is greater, 
#"Second is greater" if the second number is greater, and "The numbers are equal" otherwise.

variable1 = float (input("Enter the 1st digit: "))
variable2 = float (input("Enter the second digit: "))
if (variable1 > variable2):
    print("First is greater")
elif (variable1 < variable2):
    print("Second is greater")
else:
    print("The numbers are equal")
# Out:
# Enter the 1st digit: 20.3
# Enter the second digit: 3
# First is greater

# %% [markdown]
# Task 4

# %%
#Write the Python code of a program that reads two numbers, subtracts the smaller 
#number from the larger one, and prints the result.

number1 = int (input("First number is:"))
number2 = int (input("Second number is:"))
if (number1 > number2):
    print(number1 - number2)
else:
    print(number2 - number1)
# Out:
# First number is:20
# Second number is:30
# 10

# %% [markdown]
# Task 5

# %%
#Write the Python code of a program that reads a number, and prints "The number is even"
#or "The number is odd", depending on whether the number is even or odd. 

var1 = int (input("Enter the first number: "))
if var1%2==0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# Enter the first number: 5
# the number is odd

# %% [markdown]
# Task 6

# %%
#Write the Python code of a program that reads an integer as input from the user, and prints the
#integer if it is a multiple of 2 OR 5 and prints "Not a multiple of 2 OR 5" otherwise.

var = int (input("Enter a number: "))
if (var % 2 == 0 or var % 5 == 0):
    print(var)
else:
    print("not a multiple of 2 or 5")
# Out:
# Enter a number: 13
# not a multiple of 2 or 5

# %% [markdown]
# Task 7

# %%
# Write the Python code of a program that reads an integer, and prints the integer it is a multiple of
# either 2 or 5 but not both. If the number is a multiple of 2 and 5 both, then print "Multiple of 2
# and 5 both". For all other numbers, the program prints "Not a multiple we want".

var1 = int (input("Enter a number: "))
if (var1%2==0 and not var1%5==0):
    print(var1)
elif (not var1%2==0 and var1%5==0):
    print(var1)
elif (var1%2==0 and var1%5==0):
    print("multiple of 2 and 5 both")
else:
    print("not a multiple we want")
# Out:
# Enter a number: 15
# 15

# %% [markdown]
# Task 8

# %%
var1 = int (input("Enter a number: "))
if (var1%2==0 and var1%5==0):
    print(var1)
else:
    print("not multiple of 2 and 5 both")
# Out:
# Enter a number: 10
# 10

# %% [markdown]
# Task 9

# %%
variable = int (input("Enter time in seconds:"))
hour = (variable // 3600)
variable1 = variable % 3600
minute = variable1 // 60
second = variable1 % 60
print("hours:", hours , "minutes:", minute , "seconds:", second)
# Out:
# Enter time in seconds:5000
# hours: 1 minutes 23 seconds 20

# %% [markdown]
# Task 10

# %%
hours = int (input("Enter the working hours: "))
if (40 < hours <= 168):
    salary = 8000 + (hours - 40) * 300 
    print("Salary after working more than 40 hours= ", salary )
elif (0 <= hours <= 40):
    salary1= hours * 200
    print("Salary after working less than or equal 40 hours= ", salary1)
elif (hours > 168):
    print("Impossible to work more than 168 hours weekly")
else:
    print("Hour cannot be negative")
# Out:
# Enter the working hours: 169
# Impossible to work more than 168 hours weekly

# %% [markdown]
# Task 11

# %%
value_of_S = int (input("S= "))
value_of_L = 3000 - 125 * value_of_S**2
value_of_L1 = 12000 / (4 + value_of_S**2 / 14900)
if (value_of_S >= 100):
    print("L= ", value_of_L1)
else:
    print("L= ", value_of_L)
# Out:
# S= 120
# L=  2416.2162162162163

# %% [markdown]
# Task 12

# %%
hour = int (input("Enter the time: "))
if (4 <= hour <= 6):
    print("Breakfast")
elif (12 <= hour <= 13):
    print("Lunch")
elif (16 <= hour <= 17):
    print("Snacks")
elif (19 <= hour <= 20):
    print("Dinner")
elif (0 < hour < 23):
    print("Patience is a virtue")
else:
    print("Wrong Time")
# Out:
# Enter the time: 18
# Patience is a virtue

# %% [markdown]
# Task 13

# %%
mark = int (input("Enter your achieved mark: "))

if (90 <= mark <=100):
    print ("You have got 'A' ")
elif (80 <= mark <= 89):
    print ("You have got 'B' ")
elif (70 <= mark <= 79):
    print ("You have got 'C' ")
elif (60 <= mark <= 69):
    print ("You have got 'D' ")
elif (50 <= mark <= 59):
    print ("You have got 'E' ")
elif (0 <= mark < 50):
    print ("You have got 'F' ")
else:
    print ("You have put a wrong number ")
# Out:
# Enter your achieved mark: -10
# You have put a wrong number

# %% [markdown]
# Task 14

# %%
variable1 = int (input("Enter the distance in meters: "))
variable2 = int (input("Enter the time in seconds: "))
velocity_in_ms = variable1 / variable2
velocity = ( velocity_in_ms * 3600 ) / 1000
print ("velocity= ", velocity,"km/h")
if (velocity < 60):
    print("Too slow. Needs more changes.")
elif (60 <= velocity <= 90):
    print("velocity is okay. The car is ready!")
elif (velocity > 90):
    print("Too fast. Only a few changes should suffice.")
# Out:
# Enter the distance in meters: 25400
# Enter the time in seconds: 3600
# velocity=  25.4 km/h
# Too slow. Needs more changes.

# %% [markdown]
# Task 15

# %%
cgpa = float (input("Input your CGPA: "))
credits = int (input("Input your credits: "))
if (credits <= 30 and cgpa <= 3.80):
    print("The student is not eligible for a waiver")
elif (3.80 <= cgpa <= 3.89 and credits >= 30):
    print("The student is eligible for a waiver of 25 percent")
elif (3.90 <= cgpa <= 3.94 and credits >= 30):
    print("The student is eligible for a waiver of 50 percent")
elif (3.95 <= cgpa <= 3.99 and credits >= 30):
    print("The student is eligible for a waiver of 75 percent")
elif (cgpa == 4.00 and credits >= 30):
    print("The student is eligible for a waiver of 100 percent")
else:
    print("Not eligible.")
# Out:
# Input your CGPA: 3.90
# Input your credits: 60
# The student is eligible for a waiver of 50 percent

# %% [markdown]
# Task 16

# %%
p = 5
q = 6
r = 9
sum = 0
if (p < 12):
    print(r + 2)
else:
    print(r + p)
if (q > 20):
    print(r + 19)
elif (q <= 6):
    print(q + 3)
else:
    print(p + q + r)
if (r > 15):
    print(r)
elif (r == 0):
    print(p + q)
else:
    print(p)
if (sum != 0):
    print(3)
else:
    print(sum + 32)
if (p>0 and r<10):
    print(p+r)
else:
    print(p-r)
# Out:
# 11
# 9
# 5
# 32
# 14

# %% [markdown]
# Task 17

# %%
var1 = var2 = var3 = var4 = var5 = var6 = False
result1 = False
result2 = False
result3 = False
result4 = False
result5 = False
result6 = False
result7 = False
result8 = False
result9 = False
result10 = False
var1 = 4 > 3 - 1
var2 = var1 and False
var3 = True
var4 = False
var5 = True
var6 = var3 and False
result1 = (var1 or var2) and (8 * 10 > 45)
result2 = (var1 or var2) and (result1 and False)
result3 = (var1 and result1) or result2
result4 = (var1 or var2) or ((var3 and var1) and False)
result5 = (var1 and var2) and (result3 or var1)
result6 = ((var3 or var2) and not(result5)) or True
result7 = (var4 and result1) and ((result1 and False) or True)
result8 = ((var1 and result3) and (var5 or var6)) and True
result9 = ((result2 and var2) or (result7 and var1)) and False
result10 = not(var1 and True)
print (var1)
print (var2)
print (var3)
print (var4)
print (var5)
print (var6)
print (result1)
print (result2)
print (result3)
print (result4)
print (result5)
print (result6)
print (result7)
print (result8)
print (result9)
print (result10)
# Out:
# True
# False
# True
# False
# True
# False
# True
# False
# True
# True
# False
# True
# False
# True
# False
# False

# %% [markdown]
# Task 18

# %%
var1 = False
var2 = False
var3 = False
var4 = False
var5 = False
var6 = False
result1 = False
result2 = False
result3 = False
result4 = False
result5 = False
result6 = False
result7 = False
result8 = False
result9 = False
result10 = False
var1 = ((not True) or True) and False
var2 = var1 and False
var3 = True and not False
var4 = False
var5 = True
var6 = var3 and False
result1 = (var1 and var2) and (40 % 3) > 45 or (var5 and var6)
result2 = (var1 or var2) or (result1 and False)
result3 = (var1 and result1) or result2 or var5
result4 = (var1 or var2) or ((var3 and var1) and False)
result5 = (var1 and var2) and (result3 or var1)
result6 = ((var3 or (not var2)) and (result5)) or True
result7 = (var4 and result1) and ((result1 and False) or True)
result8 = ((var1 and result3) and ((not var5) or var6)) and True
result9 = ((result2 and var2) or ((not result7) and var1)) and not False
result10 = not(var1 and True)
print (var1)
print (var2)
print (var3)
print (var4)
print (var5)
print (var6)
print (result1)
print (result2)
print (result3)
print (result4)
print (result5)
print (result6)
print (result7)
print (result8)
print (result9)
print (result10)
# Out:
# False
# False
# True
# False
# True
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# True

# %% [markdown]
# Task 19

# %%
var1 = var2 = var3 = var4 = var5 = var6 = False
result1 = result2 = result3 = result4 = result5 = result6 = False
result7 = result8 = result9 = result10 = False
var1 = (not False or False) and True
var2 = var1 and True
var3 = False and not True
var4 = True
var5 = False
var6 = var3 and True
result1 = (var1 and var2) and ( 40 % 3 > 45) or (var5 and var6)
result2 = (var1 or var2) or (result1 and False)
result3 = (var1 and result1) or result2 or var5
result4 = (var1 or var2) or ((var3 and var1) and False)
result5 = (var1 and var2) and (result3 or var1)
result6 = ((var3 or not var2) and (result5)) or True
result7 = (var4 and result1) and ((result1 and False) or True)
result8 = ((var1 and result3) and (not var5 or var6)) and True
result9 = ((result2 and var2) or (not result7 and var1)) and not False
result10 = not (var1 and True)
print (var1)
print (var2)
print (var3)
print (var4)
print (var5)
print (var6)
print (result1)
print (result2)
print (result3)
print (result4)
print (result5)
print (result6)
print (result7)
print (result8)
print (result9)
print (result10)
# Out:
# True
# True
# False
# True
# False
# False
# False
# True
# True
# True
# True
# True
# False
# True
# True
# False

# %% [markdown]
# Task 20

# %%
var1 = int (input("Enter a number: "))
if (not var1%2==0 and not var1%5==0):
    print(var1)
else:
    print("No")
# Out:
# Enter a number: 5
# No

# %% [markdown]
# Task 21

# %%
var1 = int (input("Enter a number: "))
if (not var1%2==0 or not var1%5==0):
    print(var1)
else:
    print("No")
# Out:
# Enter a number: 14
# 14

# %%
#Task 22
canvas = int(input("Canva: "))
tubes = int(input("Tubes: "))
price = (canvas*120)+(tubes*75)
print("Previous total: ", price)
if (0<= price <=299):
    price1 = price - 0
    print("New total after discount: ", price1)
elif (300 <= price <=499):
    price1 = price - 10
    print("New total after discount: ", price1)
elif (500<= price <=749):
    price1 = price - 20
    print("New total after discount: ", price1)
elif (750<= price <=999):
    price1 = price - 50
    print("New total after discount: ", price1)
elif (price >= 1000):
    price1 = price - 150
    print("New total after discount: ", price1)
else:
    print("Not eligible.")
# Out:
# Canva: 0
# Tubes: 3
# Previous total:  225
# New total after discount:  225

# %%
#Task 23
temp = int(input("Temperature in degree Fahrenhite: "))
(degree_celsius) = ((temp)-32)*0.56
print((degree_celsius), " degrees C")
if ((degree_celsius) < 20):
    print("Winter")
elif (20 <= (degree_celsius) <=25):
    print("Autumn")
elif (25< (degree_celsius) <30):
    print("Spring")
elif (30<= (degree_celsius)):
    print("Summer")
# Out:
# Temperature in degree Fahrenhite: 82
# 28.000000000000004  degrees C
# Spring
